# %%
from  langchain_openai import ChatOpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# Bro API KEY Variable exists

# %%
llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)

llm_openai.invoke("Bro, tell me a fun fact").content
# Out:
# 'Bro — fun fact: bananas are botanically berries, but strawberries aren’t. \n\nReason: a true "berry" develops from a single ovary and has a fleshy interior (like bananas or grapes). Strawberries form from many tiny ovaries on one flower, so they’re called aggregate fruits. Want another weird one?'

# %%
from langchain.chat_models import init_chat_model

llm_openai_chat = init_chat_model(model = "gpt-5-mini")

llm_openai_chat.invoke("Hello, how are you?")
# Out:
# AIMessage(content="I'm an AI so I don't have feelings, but I'm here and ready to help. What can I do for you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 12, 'total_tokens': 46, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKc09bz1u3YE0hCqqkBL13M0pJSSs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cff04-7745-7911-a51c-460218240a8f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 34, 'total_tokens': 46, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
