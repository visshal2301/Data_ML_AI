# %%
from  langchain_openai import ChatOpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# Bro API KEY Variable exists

# %%
llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0)

llm_openai.invoke("Bro, tell me a fun fact").content
# Out:
# 'Bro — fun fact: bananas are botanically berries, but strawberries aren’t. \n\nReason: a true "berry" develops from a single ovary and has a fleshy interior (like bananas or grapes). Strawberries form from many tiny ovaries on one flower, so they’re called aggregate fruits. Want another weird one?'

# %%
from langchain.chat_models import init_chat_model

llm_openai_chat = init_chat_model(model = "gpt-5-mini")

llm_openai_chat.invoke("Hello, how are you?")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain.chat_models import init_chat_model
# ----> 3 llm_openai_chat = init_chat_model(model = "gpt-5-mini")
#       5 llm_openai_chat.invoke("Hello, how are you?")
#
# File d:\Padai\Python\Krish\workshop\level\level-2\.venv\Lib\site-packages\langchain\chat_models\base.py:475, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     467     warnings.warn(
#     468         f"{config_prefix=} has been set but no fields are configurable. Set "
#     469         f"`configurable_fields=(...)` to specify the model params that are "
#     470         f"configurable.",
#     471         stacklevel=2,
#     472     )
#     474 if not configurable_fields:
# --> 475     return _init_chat_model_helper(
#     476         cast("str", model),
#     477         model_provider=model_provider,
#     478         **kwargs,
#     479     )
#     480 if model:
#     481     kwargs["model"] = model
#
# File d:\Padai\Python\Krish\workshop\level\level-2\.venv\Lib\site-packages\langchain\chat_models\base.py:499, in _init_chat_model_helper(model, model_provider, **kwargs)
#     497 model, model_provider = _parse_model(model, model_provider)
#     498 creator_func = _get_chat_model_creator(model_provider)
# --> 499 return creator_func(model=model, **kwargs)
#
# File d:\Padai\Python\Krish\workshop\level\level-2\.venv\Lib\site-packages\langchain\chat_models\base.py:35, in _call(cls, **kwargs)
#      33 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      34     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 35     return cls(**kwargs)
#
# File d:\Padai\Python\Krish\workshop\level\level-2\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\Padai\Python\Krish\workshop\level\level-2\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1090, in BaseChatOpenAI.validate_environment(self)
#    1080         self.http_async_client = httpx.AsyncClient(
#    1081             proxy=self.openai_proxy, verify=global_ssl_context
#    1082         )
#    1083     async_specific = {
#    1084         "http_client": self.http_async_client
#    1085         or _get_default_async_httpx_client(
#    (...)   1088         "api_key": async_api_key_value,
#    1089     }
# -> 1090     self.root_async_client = openai.AsyncOpenAI(
#    1091         **client_params,
#    1092         **async_specific,  # type: ignore[arg-type]
#    1093     )
#    1094     self.async_client = self.root_async_client.chat.completions
#    1095 return self
#
# File d:\Padai\Python\Krish\workshop\level\level-2\.venv\Lib\site-packages\openai\_client.py:514, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     512     api_key = os.environ.get("OPENAI_API_KEY")
#     513 if api_key is None:
# --> 514     raise OpenAIError(
#     515         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     516     )
#     517 if callable(api_key):
#     518     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
