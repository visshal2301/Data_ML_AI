# %%
from  langchain_openai import ChatOpenAI
from langchain_openai import OpenAI
import os 
from dotenv import load_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")
# Out:
# Bro API KEY Variable exists

# %%
llm = OpenAI(model='gpt-3.5-turbo-instruct')

result = llm.invoke("What is the capital of India")

print(result)
# Out:
# The capital of India is New Delhi.

# %%
model = ChatOpenAI(model='gpt-4', temperature=1.5, max_completion_tokens=10)

result = model.invoke("What is the capital of India")

print(result.content)
# Out:
# The capital of India is New Delhi.

# %%
from langchain_openai import OpenAIEmbeddings
embedding = OpenAIEmbeddings(model='text-embedding-3-large', dimensions=32)

result = embedding.embed_query("What is the capital of India")

print(str(result))
# Out:
# [-0.28698593378067017, 0.20228329300880432, 0.09891262650489807, 0.20061153173446655, -0.4235132336616516, 0.07666889578104019, -0.04664682596921921, 0.14340008795261383, -0.19745375216007233, -0.22253020107746124, -0.10968621075153351, 0.0756472647190094, -0.1711699217557907, -0.18890918791294098, -0.18937356770038605, -0.2069270759820938, 0.07485782355070114, 0.224201962351799, 0.13411252200603485, 0.023915493860840797, 0.21249961853027344, 0.0792694166302681, 0.0970551148056984, -0.24054808914661407, -0.19875401258468628, 0.07597232609987259, 0.13940644264221191, -0.1390349268913269, 0.04295501485466957, 0.10123451799154282, 0.2533649206161499, 0.12371044605970383]
