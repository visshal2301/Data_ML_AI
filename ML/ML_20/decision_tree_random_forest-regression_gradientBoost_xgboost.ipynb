# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import joblib

# %%
data = fetch_california_housing()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target, name="MedianHouseValue")

print("Shape:", X.shape)
print("Features:", X.columns.tolist())
# Out:
# Shape: (20640, 8)
# Features: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedianHouseValue, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
dt_reg = DecisionTreeRegressor(
    criterion="squared_error",
    max_depth=8,
    min_samples_split=3,
    min_samples_leaf=2,
    splitter="best",
    random_state=2
)

# %%
dt_reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=2, min_samples_split=3,
#                       random_state=2)

# %%
y_pred = dt_reg.predict(X_test)

# %%
print("Decision Tree Performance:")
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R² score:", r2_score(y_test, y_pred))
# Out:
# Decision Tree Performance:
# MAE: 0.44196377960560507
# MSE: 0.4176395231473704
# RMSE: 0.6462503564001884
# R² score: 0.6899540008471217

# %%
for name, score in zip(data.feature_names, dt_reg.feature_importances_):
    print(f"{name}: {score:.4f}")
# Out:
# MedInc: 0.6534
# HouseAge: 0.0418
# AveRooms: 0.0280
# AveBedrms: 0.0050
# Population: 0.0096
# AveOccup: 0.1329
# Latitude: 0.0708
# Longitude: 0.0585

# %%
plt.figure(figsize=(18, 10))
plot_tree(
    dt_reg,
    feature_names=data.feature_names,
    filled=True,
    rounded=True,
    max_depth=4
)
plt.show()

# %%
joblib.dump(dt_reg, "decision_tree_regressor.pkl")
print("Decision Tree Regressor saved!")
# Out:
# Decision Tree Regressor saved!

# %%
loaded_dt_reg = joblib.load("decision_tree_regressor.pkl")

# %%
def predict_house_value_dt(features_list):
    # features_list = [MedInc, HouseAge, AveRooms, AveBedrms,Population, AveOccup, Latitude, Longitude]
    # scaled = scaler.transform(features_list)
    pred = loaded_dt_reg.predict(features_list)[0]
    return float(pred)

# %%
test = pd.DataFrame([[8.3, 29, 6.5, 1.0, 400, 3.5, 34.2, -118.4]], columns=data.feature_names)

# %%
test
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0     8.3        29       6.5        1.0         400       3.5      34.2
#
#    Longitude
# 0     -118.4

# %%
print(predict_house_value_dt(test))
# Out:
# 4.8114862500000015

# %% [markdown]
# # RANDOM FOREST REGRESSOR

# %%
rf_reg = RandomForestRegressor(
    n_estimators=100,
    max_depth=None,
    oob_score=True,
    min_samples_split=3,
    min_samples_leaf=1,
    bootstrap=True,
    max_features="sqrt",
    random_state=42
)

# %%
rf_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features='sqrt', min_samples_split=3, oob_score=True,
#                       random_state=42)

# %%
print("OOB Score (R²) (100 estimators) (None as max_Depth):", rf_reg.oob_score_)
# Out:
# OOB Score (R²) (100 estimators) (None as max_Depth): 0.8122841015234715

# %%
print("OOB Score (R²)(150 estimators)(max_dept=10):", rf_reg.oob_score_)
# Out:
# OOB Score (R²)(150 estimators)(max_dept=10): 0.8122841015234715

# %%
rf_pred = rf_reg.predict(X_test)

# %%
print("Random Forest Regression Performance:")
print("MAE:", mean_absolute_error(y_test, rf_pred))
print("MSE:", mean_squared_error(y_test, rf_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, rf_pred)))
print("R² score:", r2_score(y_test, rf_pred))
# Out:
# Random Forest Regression Performance:
# MAE: 0.33339039003207277
# MSE: 0.2497272056728984
# RMSE: 0.49972713121552487
# R² score: 0.8146082525547065

# %%
imp = rf_reg.feature_importances_
for name, score in zip(data.feature_names, imp):
    print(f"{name}: {score:.4f}")
# Out:
# MedInc: 0.3525
# HouseAge: 0.0579
# AveRooms: 0.1252
# AveBedrms: 0.0448
# Population: 0.0355
# AveOccup: 0.1216
# Latitude: 0.1308
# Longitude: 0.1317

# %%
joblib.dump(rf_reg, "random_forest_regressor.pkl")
print("Random Forest Regressor saved!")
# Out:
# Random Forest Regressor saved!

# %%
loaded_rf_reg = joblib.load("random_forest_regressor.pkl")

# %%
def predict_house_value_rf(features_list):
    # scaled = scaler.transform(features_list)
    pred = loaded_rf_reg.predict(features_list)[0]
    return float(pred)

# %%
test_rf = pd.DataFrame([[8.3, 29, 6.5, 1.0, 400, 3.5, 34.2, -118.4]], columns=data.feature_names)

# %%
print(predict_house_value_rf(test_rf))
# Out:
# 4.133891833333331

# %%
4.81 - 4.13
# Out:
# 0.6799999999999997

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gb_reg = GradientBoostingRegressor(
    n_estimators=300,
    subsample=0.8 # 0.2 will be used for OOB
)

# %%
gb_reg.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=300, subsample=0.8)

# %%
len(X_train)
# Out:
# 16512

# %%
print(len(gb_reg.oob_improvement_)) # 300 models OOB
# Out:
# 300

# %%
# gb_reg.oob_improvement_

# %%
gb_pred = gb_reg.predict(X_test)

# %%
print("Gradient Boosting Regression Performance:")
print("MAE:", mean_absolute_error(y_test, gb_pred))
print("MSE:", mean_squared_error(y_test, gb_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, gb_pred)))
print("R² score:", r2_score(y_test, gb_pred))
# Out:
# Gradient Boosting Regression Performance:
# MAE: 0.33369937870515204
# MSE: 0.2458173949076458
# RMSE: 0.4957997528313682
# R² score: 0.8175108063553526

# %% [markdown]
# # XGBoost Regression

# %%
# !pip install xgboost

# %%
import xgboost as xgb

# %%
xgb_reg = xgb.XGBRegressor(
    n_estimators=500, # number of models
    learning_rate=0.05, # lr / alpha
    max_depth=6, # max depth of each tree
    subsample=0.8, # Use 80% of random data in each tree
    colsample_bytree=0.8, # 80% of the unique columns names for each tree
    reg_lambda=1.0,       # L2 regularization
    reg_alpha=0.0,        # L1 regularization
    objective='reg:squarederror',
    random_state=20,
    tree_method="hist"
)

# %%
xgb_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_pred = xgb_reg.predict(X_test)
print("Xtreme Gradient Boosting Regression Performance:")
print("MAE:", mean_absolute_error(y_test, xgb_pred))
print("MSE:", mean_squared_error(y_test, xgb_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, xgb_pred)))
print("R² score:", r2_score(y_test, xgb_pred))
# Out:
# Xtreme Gradient Boosting Regression Performance:
# MAE: 0.2921935745694471
# MSE: 0.20180515780573544
# RMSE: 0.44922728969390924
# R² score: 0.8501844813092434
